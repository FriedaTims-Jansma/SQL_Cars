# %% [markdown]
# ### You will use SQLite language in this exercise.

# %% [markdown]
# # Load Data
#
# Just Shift + Enter to run this shell

# %%
# Just Shift + Enter to run this shell

import pandas as pd
import pandasql as ps

file_location = "Salesforce 02.xlsx"

# this is your expected output, which means your answer will look like this
# this only stores the first 5 rows of the answers. If you get the same output, then your answer is considered correct.
expected_output = pd.read_excel(file_location, sheet_name = "expected_output")

# this is your SQL data base
salesforce_employees = pd.read_excel(file_location, sheet_name = "salesforce_employees")
# Out:
# /Users/samtims/.pyenv/versions/3.8.12/envs/frieda/lib/python3.8/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
# Just Shift + Enter to run this shell

salesforce_employees.head()
# Out:
#    id first_name last_name  age sex employee_title  department  salary  \
# 0  11    Lorentz     Yeung   49   M        Manager  Management  260000
# 1   7        Bat     Nicky   81   F          Sales       Sales    1400
# 2  21        Lee     Suzan   73   F          Sales       Sales    1300
# 3  12   Shandler      Bing   35   M        Auditor  Management    1100
# 4  20      Bicky    Sarrah   13   F   Senior Sales       Sales    2000
#
#    target  bonus                 email     city              address  \
# 0     500    300   Richerd@company.com  Alabama                  NaN
# 1     400    100     Molly@company.com  Arizona  3461 Preston Street
# 2     200    150     Suzan@company.com  Florida   1275 Monroe Avenue
# 3     200    150  Shandler@company.com  Arizona                  NaN
# 4     200    150    Sarrah@company.com  Florida    1176 Tyler Avenue
#
#    manager_id
# 0           1
# 1          13
# 2          19
# 3          11
# 4          19

# %% [markdown]
# # Expected Output

# %%
# Just Shift + Enter to run this shell

expected_output.head()
# Out:
#   first_name last_name  target
# 0    Lorentz     Yeung     500

# %%
# Just Shift + Enter to run this shell
# this is a demo shell to show and test the basic SQL query.

ps.sqldf(
    """
    SELECT * 
    FROM salesforce_employees
    LIMIT 5
    """
)
# Out:
#    id first_name last_name  age sex employee_title  department  salary  \
# 0  11    Lorentz     Yeung   49   M        Manager  Management  260000
# 1   7        Bat     Nicky   81   F          Sales       Sales    1400
# 2  21        Lee     Suzan   73   F          Sales       Sales    1300
# 3  12   Shandler      Bing   35   M        Auditor  Management    1100
# 4  20      Bicky    Sarrah   13   F   Senior Sales       Sales    2000
#
#    target  bonus                 email     city              address  \
# 0     500    300   Richerd@company.com  Alabama                 None
# 1     400    100     Molly@company.com  Arizona  3461 Preston Street
# 2     200    150     Suzan@company.com  Florida   1275 Monroe Avenue
# 3     200    150  Shandler@company.com  Arizona                 None
# 4     200    150    Sarrah@company.com  Florida    1176 Tyler Avenue
#
#    manager_id
# 0           1
# 1          13
# 2          19
# 3          11
# 4          19

# %% [markdown]
# # Your Answer here
#
# 1. Now you can try to answer the question and query with sqlite syntax!
# 2. After puting in your answers, press Shift + Enter , or simply run the cell to see if you can get the same output as the expected output.
# 3. You can also check out the "Answer.ipynb" if you have problems with answering the question.

# %%
test = "Frieda"

# %%
ps.sqldf(
    """

    Enter your SQLite query here, then hit Shift + Enter.

    """
    ).head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/.pyenv/versions/3.8.12/envs/frieda/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1798                 if not evt_handled:
# -> 1799                     self.dialect.do_execute(
#    1800                         cursor, statement, parameters, context
#
# ~/.pyenv/versions/3.8.12/envs/frieda/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#
# OperationalError: near "Enter": syntax error
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ~/.pyenv/versions/3.8.12/envs/frieda/lib/python3.8/site-packages/pandasql/sqldf.py in __call__(self, query, env)
#      60             try:
# ---> 61                 result = read_sql(query, conn)
#      62             except DatabaseError as ex:
#
# ~/.pyenv/versions/3.8.12/envs/frieda/lib/python3.8/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     627     else:
# --> 628         return pandas_sql.read_query(
#     629             sql,
#
# ~/.pyenv/versions/3.8.12/envs/frieda/lib/python3.8/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1578
# -> 1579         result = self.execute(*args)
#    1580         columns = result.keys()
#
# ~/.pyenv/versions/3.8.12/envs/frieda/lib/python3.8/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1423         """Simple passthrough to SQLAlchemy connectable"""
# -> 1424         return self.connectable.execution_options().execute(*args, **kwargs)
#    1425
#
# ~/.pyenv/versions/3.8.12/envs/frieda/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1270
# -> 1271             return self._exec_driver_sql(
#    1272                 statement,
#
# ~/.pyenv/versions/3.8.12/envs/frieda/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1574         dialect = self.dialect
# -> 1575         ret = self._execute_context(
#    1576             dialect,
#
# ~/.pyenv/versions/3.8.12/envs/frieda/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1841         except BaseException as e:
# -> 1842             self._handle_dbapi_exception(
#    1843                 e, statement, parameters, cursor, context
#
# ~/.pyenv/versions/3.8.12/envs/frieda/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2022             elif should_wrap:
# -> 2023                 util.raise_(
#    2024                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#
# ~/.pyenv/versions/3.8.12/envs/frieda/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~/.pyenv/versions/3.8.12/envs/frieda/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1798                 if not evt_handled:
# -> 1799                     self.dialect.do_execute(
#    1800                         cursor, statement, parameters, context
#
# ~/.pyenv/versions/3.8.12/envs/frieda/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#
# OperationalError: (sqlite3.OperationalError) near "Enter": syntax error
# [SQL:
#
#     Enter your SQLite query here, then hit Shift + Enter.
#
#     ]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
#
# During handling of the above exception, another exception occurred:
#
# PandaSQLException                         Traceback (most recent call last)
# /var/folders/tl/1lvrxnm97c9g3s3j8smwx0kw0000gn/T/ipykernel_31555/3349847562.py in <module>
# ----> 1 ps.sqldf(
#       2     """
#       3
#       4     Enter your SQLite query here, then hit Shift + Enter.
#       5
#
# ~/.pyenv/versions/3.8.12/envs/frieda/lib/python3.8/site-packages/pandasql/sqldf.py in sqldf(query, env, db_uri)
#     154     >>> sqldf("select avg(x) from df;", locals())
#     155     """
# --> 156     return PandaSQL(db_uri)(query, env)
#
# ~/.pyenv/versions/3.8.12/envs/frieda/lib/python3.8/site-packages/pandasql/sqldf.py in __call__(self, query, env)
#      61                 result = read_sql(query, conn)
#      62             except DatabaseError as ex:
# ---> 63                 raise PandaSQLException(ex)
#      64             except ResourceClosedError:
#      65                 # query returns nothing
#
# PandaSQLException: (sqlite3.OperationalError) near "Enter": syntax error
# [SQL:
#
#     Enter your SQLite query here, then hit Shift + Enter.
#
#     ]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
